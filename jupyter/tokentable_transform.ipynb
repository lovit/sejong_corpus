# %% [markdown]
# 세종말뭉치의 품사정보는 형태소분석을 하기 위한 자료이며, 데이터분석의 수준에서는 일반명사/고유명사 등을 분리하거나 목적격/주격 조사를 구분할 필요가 없기 때문에 품사를 단순화 하여 볼 필요가 있다. 또한 비지도학습 기반 토크나이저인 soynlp tokenizers를 위해서도 품사는 합쳐질 필요가 있다. 아래는 '진짜했다니까' 라는 띄어쓰기 오류가 있는 짧은 문장에 대하여 우리가 기대하는 결과이다. '했다니까'는 '하다/동사'가 활용이 된 형태이며, 한국어 품사에 '어미(Eomi)'는 존재하지 않는다. Suffix인 '어미'는 형태소이다. 형태소분석과 품사판별을 나눠서 풀어보자
#
#     Part of speech tagging: 진짜/명사 + 했다니까/동사
#     Morphological analysis: 진짜/명사 + 하/동사 + 았/선어말어미 + 다니까/어말어미
#     POS tagging + Lemmatization: 진짜/명사 + 하다/동사
#     L/R POS tagging:  진짜/명사 + 했/동사R + 다니까/어미E
#
# 특히 용언이 활용되었을 때가 까다로운데, lemmatization을 하지 않는 품사판별이나 L/R pos tagging에서는 surfacial form 그대로 단어를 인식한다. 단, 명사의 경우 -ㄴ, -ㄹ은 hard rules로 분리한다.
#
#     진짠데 = 진짜 + ㄴ데
#
# 아래는 품사판별을 위한 사전 형성이다. 품사 판별은 단어의 surfacial form만 보고도 맞출 수 있어야 한다. 토크나이징이 된 단어열 (word sequence)에 대하여 tagging이 되면 된다. Surfacial form을 인식하면 되기 때문에 character-level로 작업을 할 수 있다. Word segmentation + Tagging이 되면 품사 판별이 가능하다.

# %% [markdown]
# ## 품사 판별 (Part of Speech Tagging)을 위한 사전 구축

# %%
with open('../../sejong/data/processed/lr/tokentable_simple.txt', encoding='utf-8') as f:
    for _ in range(10):
        print(next(f).strip())
# Out:
# 그	그/MM	그/Determiner	80726
# 수	수/NNB	수/Noun	67991
# 이	이/MM	이/Determiner	45777
# 것이다.	것/NNB+이/VCP+다/EF+./SF	것/Noun+이/Adjective+다/Eomi	37808
# 있다.	있/VX+다/EF+./SF	있/Verb+다/Eomi	30548
# 한	한/MM	한/Determiner	30536
# 있는	있/VX+는/ETM	있/Verb+는/Eomi	28946
# 있다.	있/VV+다/EF+./SF	있/Verb+다/Eomi	26195
# 있는	있/VV+는/ETM	있/Verb+는/Eomi	25045
# 것은	것/NNB+은/JX	것/Noun+은/Josa	24816

# %%
'abc'.split()[3:]
# Out:
# []

# %%
from soynlp.hangle import normalize

def as_lr(text, morphomes):
    text = normalize(text, english=True, number=True)
    
    if morphomes[0][1] == 'Adverb':
        adverb_end_index = max([idx for idx, (_, _) in filter(lambda x:x[1][1] == 'Adverb', enumerate(morphomes))]) + 1
        morphomes = [(''.join([w for w,_ in morphomes[:adverb_end_index]]), 'Adverb')] + morphomes[adverb_end_index:]
    if morphomes[0][1] == 'Adverb' and len(morphomes) >= 2 and (morphomes[1][1] == 'Verb' or morphomes[1][1] == 'Adjective'):
        morphomes = [(morphomes[0][0]+morphomes[1][0], morphomes[1][1])] + morphomes[2:]
    if morphomes[0][1] == 'Exclamation':
        all_Exclamation = True
        for _, tag in morphomes:
            if tag != 'Exclamation':
                all_Exclamation = False
        if all_Exclamation:
            morphomes = [(text, 'Exclamation')]
    
    if len(morphomes) == 1:
        return morphomes
    
    if morphomes[0][1] == 'Noun':
        noun_end_index = max([idx for idx, (_, _) in filter(lambda x:x[1][1] == 'Noun', enumerate(morphomes))]) + 1
        L = ''.join([w for w, _ in morphomes[:noun_end_index]])
        if noun_end_index == len(morphomes):
            return [(L, 'Noun')]
        R = text[len(L):]
        return [(L, 'Noun'), (R, morphomes[noun_end_index][1], morphomes[noun_end_index:])]
    if (morphomes[0][1] == 'Verb' or morphomes[0][1] == 'Adjective') and (morphomes[-1][1] == 'Eomi', morphomes[-1][1] == 'Josa'):
        return [(text, morphomes[0][1], morphomes)]
    if (morphomes[0][1] == 'Adverb') and (morphomes[-1][1] == 'Noun'):
        return [(text, 'Noun')]
    if (morphomes[0][1] == 'Adverb') and (morphomes[-1][1] == 'Josa' or morphomes[-1][1] == 'Eomi'):
        return [(text, 'Adverb')]
    if (morphomes[0][1] == 'Adverb' or morphomes[0][1] == 'Determiner') and (morphomes[-1][1] == 'Determiner'):
        return [(text, 'Determiner')]
    if (morphomes[0][1] == 'Exclamation') and (morphomes[-1][1] == 'Josa' or morphomes[-1][1] == 'Eomi'):
        return [(text, 'Exclamation')]
    if morphomes[-1][1] == 'Noun':
        return [(text, 'Noun')]
#     if

# %%
from collections import defaultdict
stem_table = defaultdict(lambda: defaultdict(lambda: 0))

with open('../../sejong/data/processed/lr/tokentable_simple.txt', encoding='utf-8') as fi:
    with open('../../sejong/data/processed/lr/tokentable_simple_lr.txt', 'w', encoding='utf-8') as fo:
        for line in fi:
            text, row, pos, count = line.strip().split('\t')
            pos_ = [m.split('/') for m in pos.split('+')]
            lr = as_lr(text, pos_)
            if lr:
                if len(lr[-1]) == 3:
                    R = '{}/{}'.format(lr[-1][0], lr[-1][1])
                    stem = tuple([tuple(m) for m in lr[-1][2]])
                    stem_table[R][stem] += int(count.strip())
                    lr[-1] = lr[-1][:2]
                lr_ = '+'.join(['{}/{}'.format(w,t) for w,t in lr])
                fo.write('{}\t{}\t{}\t{}\t{}\n'.format(text, row, pos, lr_, count.strip()))
#             else:
#                 print('{}\t{}\t\t{}\n{}\n'.format(text, morphomes, count.strip(), lr))

# %%
from soynlp.hangle import decompose, compose

def complify_jamo(s):
    last = s[-1][0]
    if len(last) >= 2:
        # ㅏㅆ다 -> 았다
        if (12623 <= ord(last[0]) <= 12643) and (12593 <= ord(last[1]) <= 12622):
            s = tuple(list(s[:-1]) + [(compose('ㅇ', last[0], last[1]) + last[2:], s[-1][1])])
    return s

def hangle_normalizer(w):
    replacer = {
        'ᆼ':'ㅇ',
        'ᄆ':'ㅁ',
        'ᄇ':'ㅂ',
        'ᆯ':'ㄹ',
        'ᆫ':'ㄴ'
    }
    return ''.join([replacer.get(c, c) for c in w])

def clean_stem_table(stem_table):    
    clean_table = {}
    for R, stems in sorted(stem_table.items(), key=lambda x:-sum(x[1].values())):
        R = R.strip()
        R = normalize(R.split('/')[0]) + '/' + R.split('/')[1]
        if (not R) or (R[0] == '/') or (R in clean_table) or (' ' in R):
            continue
        freq = sum(stems.values())
#         if freq <= 1:
#             continue
            
        if len(stems) == 1:
            best = list(stems.keys())[0]
        
        best = sorted(stems.items(), key=lambda x:-x[1])[0][0]
        best = complify_jamo(best)
        best = [(hangle_normalizer(w), t) for w,t in best]
        if (len(best) == 1) and (best[0][1] == 'Josa' or best[0][1] == 'Eomi') and (R.split('/')[0] != best[0][0]):
            continue
        clean_table[R] = ('+'.join(['{}/{}'.format(m, tag) for m,tag in best]), freq)
    return clean_table

# %%
clean_table = clean_stem_table(stem_table)
len(clean_table)
# Out:
# 176064

# %%
for R, stem in sorted(clean_table.items(), key=lambda x:x[1][1])[100:130]:
    print('%s --> %s'%(R, stem))
# Out:
# 둘러댔는데/Verb --> ('둘러대/Verb+었는데/Eomi', 1)
# 살겠다니/Verb --> ('살/Verb+겠다니/Eomi', 1)
# 그렇구말구요/Adjective --> ('그렇/Adjective+구말구요/Eomi', 1)
# 벗어달라고/Verb --> ('벗/Verb+어달라고/Eomi', 1)
# 일으키려다가/Verb --> ('일으키/Verb+려다가/Eomi', 1)
# 불으락푸르락했다/Verb --> ('불그락푸르락하/Verb+았다/Eomi', 1)
# 많으시리라/Adjective --> ('많/Adjective+으시리라/Eomi', 1)
# 나쁘구/Adjective --> ('나쁘/Adjective+구/Eomi', 1)
# 거치다가는/Verb --> ('거치/Verb+다가는/Eomi', 1)
# 더웠다가/Adjective --> ('덥/Adjective+었다가/Eomi', 1)
# 부럴/Adjective --> ('부럽/Adjective+ㄹ/Eomi', 1)
# 우러나오게/Verb --> ('우러나오/Verb+게/Eomi', 1)
# 낳는/Adjective --> ('낳/Adjective+는/Eomi', 1)
# 밝혀내자/Verb --> ('밝혀내/Verb+자/Eomi', 1)
# 밝혀놓았으므로/Verb --> ('밝히/Verb+어놓았으므로/Eomi', 1)
# 해먹습니다/Verb --> ('하/Verb+아먹습니다/Eomi', 1)
# 줏었다/Verb --> ('줏/Verb+었다/Eomi', 1)
# 지낸다고만/Verb --> ('지내/Verb+ㄴ다고만/Eomi', 1)
# 짓이겼지만/Verb --> ('짓이기/Verb+었지만/Eomi', 1)
# 파헤치겠다는/Verb --> ('파헤치/Verb+겠다는/Eomi', 1)
# 더해가며/Verb --> ('더하/Verb+아가며/Eomi', 1)
# 흥치며/Verb --> ('흥치/Verb+며/Eomi', 1)
# 게에/Josa --> ('게에/Josa', 1)
# 잘해봤자/Verb --> ('잘하/Verb+아보았자/Eomi', 1)
# 맡겼단다/Verb --> ('맡기/Verb+었단다/Eomi', 1)
# 되었느냐구/Verb --> ('되/Verb+었느냐구/Eomi', 1)
# 허소/Adjective --> ('허/Adjective+소/Eomi', 1)
# 마르므로/Verb --> ('마르/Verb+므로/Eomi', 1)
# 짓밟히지/Verb --> ('짓밟히/Verb+지/Eomi', 1)
# 이/Exclamation --> ('이/Exclamation', 1)

# %%
for R, stem in sorted(clean_table.items(), key=lambda x:-x[1][1])[100:130]:
    print('%s --> %s'%(R, stem))
# Out:
# 않은/Verb --> ('않/Verb+은/Eomi', 6135)
# 좋은/Adjective --> ('좋/Adjective+은/Eomi', 6105)
# 밖에/Josa --> ('밖에/Josa', 5901)
# 있어/Verb --> ('있/Verb+어/Eomi', 5823)
# 했던/Verb --> ('하/Verb+았던/Eomi', 5763)
# 일/Adjective --> ('이/Adjective+ㄹ/Eomi', 5748)
# 되지/Verb --> ('되/Verb+지/Eomi', 5670)
# 지난/Verb --> ('지나/Verb+ㄴ/Eomi', 5667)
# 마다/Josa --> ('마다/Josa', 5381)
# 들어/Verb --> ('들/Verb+어/Eomi', 5369)
# 해도/Verb --> ('하/Verb+아도/Eomi', 5353)
# 이라/Adjective --> ('이/Adjective+라/Eomi', 5311)
# 돼/Verb --> ('되/Verb+어/Eomi', 5150)
# 인데/Adjective --> ('이/Adjective+ㄴ데/Eomi', 5113)
# 으로는/Josa --> ('으로는/Josa', 4960)
# 크게/Adjective --> ('크/Adjective+게/Eomi', 4660)
# 있다고/Verb --> ('있/Verb+다고/Eomi', 4566)
# 있던/Verb --> ('있/Verb+던/Eomi', 4525)
# 알/Verb --> ('알/Verb+ㄹ/Eomi', 4458)
# 않을/Verb --> ('않/Verb+을/Eomi', 4396)
# 알고/Verb --> ('알/Verb+고/Eomi', 4388)
# 온/Verb --> ('오/Verb+ㄴ/Eomi', 4274)
# 있는데/Verb --> ('있/Verb+는데/Eomi', 4132)
# 한테/Josa --> ('한테/Josa', 4131)
# 보다는/Josa --> ('보다는/Josa', 4098)
# 않는다/Verb --> ('않/Verb+는다/Eomi', 4049)
# 주는/Verb --> ('주/Verb+는/Eomi', 4001)
# 보는/Verb --> ('보/Verb+는/Eomi', 3964)
# 했다/Adjective --> ('하/Adjective+았다/Eomi', 3936)
# 가는/Verb --> ('가/Verb+는/Eomi', 3908)

# %% [markdown]
# #### to DataFrame

# %%
data = [
    {
        'Word': R.split('/')[0],
        'Tag': R.split('/')[1],
        'Stem': stem,
        'Frequency': freq
    }
    for R, (stem, freq) in sorted(clean_table.items(), key=lambda x:-x[1][1])
]

import pandas as pd
stem_table_df = pd.DataFrame(data, columns=['Word', 'Tag', 'Stem', 'Frequency'])
stem_table_df.to_csv('../data/processed/lr/stem_table.csv', encoding='utf-8')

# %%
stem_table_df
# Out:
#            Word        Tag                     Stem  Frequency
# 0             을       Josa                   을/Josa     495674
# 1             의       Josa                   의/Josa     464361
# 2             이       Josa                   이/Josa     379235
# 3             에       Josa                   에/Josa     340265
# 4             를       Josa                   를/Josa     281138
# 5             가       Josa                   가/Josa     249587
# 6             은       Josa                   은/Josa     245650
# 7             는       Josa                   는/Josa     214588
# 8            으로       Josa                  으로/Josa     139157
# 9             도       Josa                   도/Josa     114151
# 10            한  Adjective       하/Adjective+ㄴ/Eomi     108837
# 11           에서       Josa                  에서/Josa     107734
# 12            로       Josa                   로/Josa     100050
# 13           이다  Adjective       이/Adjective+다/Eomi      93699
# 14            과       Josa                   과/Josa      89863
# 15           하는       Verb            하/Verb+는/Eomi      88054
# 16            인  Adjective       이/Adjective+ㄴ/Eomi      64985
# 17           하고       Verb            하/Verb+고/Eomi      64139
# 18            할       Verb            하/Verb+ㄹ/Eomi      62905
# 19            와       Josa                   와/Josa      60735
# 20           있다       Verb            있/Verb+다/Eomi      58104
# 21           있는       Verb            있/Verb+는/Eomi      55465
# 22            한       Verb            하/Verb+ㄴ/Eomi      51829
# 23           했다       Verb           하/Verb+았다/Eomi      47769
# 24           한다       Verb           하/Verb+ㄴ다/Eomi      40431
# 25           에는       Josa                  에는/Josa      33286
# 26            해       Verb            하/Verb+아/Eomi      32334
# 27            된       Verb            되/Verb+ㄴ/Eomi      30787
# 28           에게       Josa                  에게/Josa      28208
# 29           하게  Adjective       하/Adjective+게/Eomi      22952
# ...         ...        ...                      ...        ...
# 176034     퍼래지는  Adjective    퍼렇/Adjective+어지는/Eomi          1
# 176035     썩다남은       Verb          썩/Verb+다남은/Eomi          1
# 176036    후질근하다  Adjective    후질근하/Adjective+다/Eomi          1
# 176037    내려받거나       Verb        내리/Verb+어받거나/Eomi          1
# 176038     뜨라시는       Verb         뜨/Verb+라하시는/Eomi          1
# 176039   주어야겠구나       Verb        주/Verb+어야겠구나/Eomi          1
# 176040      깔려진       Verb         깔리/Verb+어지ㄴ/Eomi          1
# 176041    맞물려오는       Verb        맞물리/Verb+어오는/Eomi          1
# 176042   찾아내고서는       Verb        찾아내/Verb+고서는/Eomi          1
# 176043  그렇잖다니까요  Adjective  그렇/Adjective+잖다니까요/Eomi          1
# 176044   졸라매겠다는       Verb        졸라매/Verb+겠다는/Eomi          1
# 176045     끙끙대고       Verb          끙끙대/Verb+고/Eomi          1
# 176046     내비둬유       Verb         내비두/Verb+어유/Eomi          1
# 176047  들어맞았습니다       Verb       들어맞/Verb+았습니다/Eomi          1
# 176048     지쳤으니       Verb         지치/Verb+었으니/Eomi          1
# 176049     당하잖아       Verb           당하/Verb+아/Eomi          1
# 176050   생겨났다고는       Verb       생겨나/Verb+았다고는/Eomi          1
# 176051  상관없었으리라  Adjective  상관없/Adjective+었으리라/Eomi          1
# 176052    남겨줬으니       Verb       남기/Verb+어주었으니/Eomi          1
# 176053    뛰놀다가는       Verb         뛰놀/Verb+다가는/Eomi          1
# 176054    어물거리던       Verb         어물거리/Verb+던/Eomi          1
# 176055      우셨나       Verb          울/Verb+시었나/Eomi          1
# 176056    떠나랴는데       Verb         떠나/Verb+랴는데/Eomi          1
# 176057       걷죠       Verb            걷/Verb+죠/Eomi          1
# 176058      다하다       Verb           다하/Verb+다/Eomi          1
# 176059    때리는구나       Verb         때리/Verb+는구나/Eomi          1
# 176060   어두웠으므로  Adjective   어둡/Adjective+었으므로/Eomi          1
# 176061   길어올린다는       Verb       길/Verb+어올리ㄴ다는/Eomi          1
# 176062  되어져버렸거나       Verb     되/Verb+어지어버리었거나/Eomi          1
# 176063    놓쳐버릴까       Verb       놓치/Verb+어버리ㄹ까/Eomi          1
#
# [176064 rows x 4 columns]

# %%
for R, stems in sorted(stem_table.items(), key=lambda x:-sum(x[1].values()))[:100]:
    print('\n%s'%R)
    for stem, count in sorted(stems.items(), key=lambda x:-x[1]):
        print('  > %s (%d)' % (stem, count))
# Out:
# 을/Josa
#   > (('을', 'Josa'),) (495523)
#   > (('에서을', 'Josa'),) (88)
#   > (('ᆯ', 'Josa'),) (19)
#   > (('를', 'Josa'),) (15)
#   > (('만을', 'Josa'),) (13)
#   > (('이을', 'Josa'),) (13)
#   > (('과을', 'Josa'),) (3)
#
# 의/Josa
#   > (('의', 'Josa'),) (464320)
#   > (('에서의', 'Josa'),) (22)
#   > (('이의', 'Josa'),) (9)
#   > (('과의', 'Josa'),) (8)
#   > (('을', 'Josa'),) (1)
#   > (('는의', 'Josa'),) (1)
#
# 이/Josa
#   > (('이', 'Josa'),) (379141)
#   > (('의', 'Josa'),) (34)
#   > (('에서이', 'Josa'),) (28)
#   > (('만이', 'Josa'),) (17)
#   > (('이이', 'Josa'),) (11)
#   > (('같이', 'Josa'),) (3)
#   > (('과이', 'Josa'),) (1)
#
# 에/Josa
#   > (('에', 'Josa'),) (340218)
#   > (('에서에', 'Josa'),) (17)
#   > (('의', 'Josa'),) (12)
#   > (('이에', 'Josa'),) (6)
#   > (('에에', 'Josa'),) (3)
#   > (('에서', 'Josa'),) (2)
#   > (('이', 'Josa'),) (2)
#   > (('는에', 'Josa'),) (2)
#   > (('밖에', 'Josa'),) (1)
#   > (('도', 'Josa'),) (1)
#   > (('의집에', 'Josa'),) (1)
#
# 를/Josa
#   > (('를', 'Josa'),) (281127)
#   > (('을', 'Josa'),) (10)
#   > (('에', 'Josa'),) (1)
#
# 가/Josa
#   > (('가', 'Josa'),) (249582)
#   > (('ᆫ가', 'Josa'),) (2)
#   > (('과', 'Josa'),) (1)
#   > (('인가', 'Josa'),) (1)
#   > (('이신가', 'Josa'),) (1)
#
# 은/Josa
#   > (('은', 'Josa'),) (245608)
#   > (('에서은', 'Josa'),) (34)
#   > (('에', 'Josa'),) (1)
#   > (('는', 'Josa'),) (1)
#   > (('만은', 'Josa'),) (1)
#   > (('이은', 'Josa'),) (1)
#   > (('랑은', 'Josa'),) (1)
#   > (('도', 'Josa'),) (1)
#   > (('ㅣ', 'Josa'),) (1)
#   > (('은커녕', 'Josa'),) (1)
#
# 는/Josa
#   > (('는', 'Josa'),) (214340)
#   > (('에는', 'Josa'),) (130)
#   > (('로는', 'Josa'),) (59)
#   > (('보다는', 'Josa'),) (21)
#   > (('과는', 'Josa'),) (18)
#   > (('ᆯ하는', 'Josa'),) (5)
#   > (('ㅣ', 'Josa'),) (4)
#   > (('에서는', 'Josa'),) (4)
#   > (('은', 'Josa'),) (3)
#   > (('와는', 'Josa'),) (1)
#   > (('는는', 'Josa'),) (1)
#   > (('가', 'Josa'),) (1)
#   > (('까지는', 'Josa'),) (1)
#
# 으로/Josa
#   > (('으로', 'Josa'),) (139148)
#   > (('에서으로', 'Josa'),) (4)
#   > (('만으로', 'Josa'),) (3)
#   > (('로', 'Josa'),) (1)
#   > (('으로까지', 'Josa'),) (1)
#
# 도/Josa
#   > (('도', 'Josa'),) (112922)
#   > (('에도', 'Josa'),) (1206)
#   > (('과도', 'Josa'),) (6)
#   > (('이도', 'Josa'),) (3)
#   > (('의집도', 'Josa'),) (2)
#   > (('두', 'Josa'),) (2)
#   > (('마저도', 'Josa'),) (2)
#   > (('하고', 'Josa'),) (1)
#   > (('ᆯ하아도', 'Josa'),) (1)
#   > (('만도', 'Josa'),) (1)
#   > (('는', 'Josa'),) (1)
#   > (('에만도', 'Josa'),) (1)
#   > (('에서도', 'Josa'),) (1)
#   > (('와도', 'Josa'),) (1)
#   > (('서도', 'Josa'),) (1)
#
# 한/Adjective
#   > (('하', 'Adjective'), ('ᆫ', 'Eomi')) (105856)
#   > (('하', 'Adjective'), ('ㄴ', 'Eomi')) (2970)
#   > (('하', 'Adjective'), ('ᆫ', 'Josa')) (6)
#   > (('만하', 'Adjective'), ('ᆫ', 'Eomi')) (2)
#   > (('하', 'Adjective'), ('ᆫ지', 'Eomi')) (1)
#   > (('하', 'Adjective'), ('ㄴ', 'Josa')) (1)
#   > (('한', 'Adjective'), ('ㄴ', 'Eomi')) (1)
#
# 에서/Josa
#   > (('에서', 'Josa'),) (107726)
#   > (('에', 'Josa'),) (7)
#   > (('에서에서', 'Josa'),) (1)
#
# 로/Josa
#   > (('로', 'Josa'),) (99305)
#   > (('으로', 'Josa'),) (466)
#   > (('ㄹ로', 'Josa'),) (253)
#   > (('ᆯ로', 'Josa'),) (15)
#   > (('대로', 'Josa'),) (6)
#   > (('에로', 'Josa'),) (4)
#   > (('ᆯ으로', 'Josa'),) (1)
#
# 이다/Adjective
#   > (('이', 'Adjective'), ('다', 'Eomi')) (93699)
#
# 과/Josa
#   > (('과', 'Josa'),) (89844)
#   > (('에서과', 'Josa'),) (15)
#   > (('이과', 'Josa'),) (3)
#   > (('와', 'Josa'),) (1)
#
# 하는/Verb
#   > (('하', 'Verb'), ('는', 'Eomi')) (88015)
#   > (('하', 'Verb'), ('는데', 'Eomi')) (29)
#   > (('하', 'Verb'), ('는', 'Josa')) (5)
#   > (('당하', 'Verb'), ('는', 'Eomi')) (5)
#
# /Josa
#   > (('의', 'Josa'),) (14935)
#   > (('ᆫ', 'Josa'),) (14498)
#   > (('이', 'Josa'),) (12624)
#   > (('ᆯ', 'Josa'),) (7976)
#   > (('ㅣ', 'Josa'),) (7247)
#   > (('을', 'Josa'),) (5501)
#   > (('ㄴ', 'Josa'),) (4158)
#   > (('ㄹ', 'Josa'),) (2971)
#   > (('가', 'Josa'),) (2679)
#   > (('에', 'Josa'),) (2599)
#   > (('은', 'Josa'),) (1373)
#   > (('과', 'Josa'),) (925)
#   > (('로', 'Josa'),) (857)
#   > (('도', 'Josa'),) (696)
#   > (('를', 'Josa'),) (238)
#   > (('는', 'Josa'),) (221)
#   > (('만', 'Josa'),) (88)
#   > (('에서', 'Josa'),) (39)
#   > (('랑', 'Josa'),) (36)
#   > (('에도', 'Josa'),) (36)
#   > (('보다는', 'Josa'),) (35)
#   > (('으로', 'Josa'),) (33)
#   > (('와', 'Josa'),) (28)
#   > (('나', 'Josa'),) (26)
#   > (('아', 'Josa'),) (24)
#   > (('야', 'Josa'),) (24)
#   > (('엔', 'Josa'),) (24)
#   > (('보다', 'Josa'),) (21)
#   > (('두', 'Josa'),) (15)
#   > (('ᆯ요', 'Josa'),) (11)
#   > (('루', 'Josa'),) (10)
#   > (('란', 'Josa'),) (6)
#   > (('이나', 'Josa'),) (5)
#   > (('보다ㄴ', 'Josa'),) (4)
#   > (('에는', 'Josa'),) (4)
#   > (('서', 'Josa'),) (4)
#   > (('마저', 'Josa'),) (3)
#   > (('뿐', 'Josa'),) (3)
#   > (('다', 'Josa'),) (3)
#   > (('을요', 'Josa'),) (2)
#   > (('요', 'Josa'),) (2)
#   > (('을하아', 'Josa'),) (2)
#   > (('까지', 'Josa'),) (2)
#   > (('보다두', 'Josa'),) (2)
#   > (('ᆯ하아', 'Josa'),) (2)
#   > (('보다도', 'Josa'),) (2)
#   > (('에선', 'Josa'),) (1)
#   > (('이는', 'Josa'),) (1)
#   > (('와는', 'Josa'),) (1)
#   > (('만을', 'Josa'),) (1)
#   > (('보단', 'Josa'),) (1)
#   > (('에만', 'Josa'),) (1)
#   > (('으로써', 'Josa'),) (1)
#   > (('하고', 'Josa'),) (1)
#   > (('에두', 'Josa'),) (1)
#   > (('한테', 'Josa'),) (1)
#   > (('하구', 'Josa'),) (1)
#   > (('하며', 'Josa'),) (1)
#
# 인/Adjective
#   > (('이', 'Adjective'), ('ᆫ', 'Eomi')) (63123)
#   > (('이', 'Adjective'), ('ㄴ', 'Eomi')) (1836)
#   > (('(이)', 'Adjective'), ('ㄴ', 'Eomi')) (10)
#   > (('이', 'Adjective'), ('ᆫ', 'Josa')) (8)
#   > (('이', 'Adjective'),) (5)
#   > (('이', 'Adjective'), ('ㄴ', 'Josa')) (2)
#   > (('이', 'Adjective'), ('은', 'Eomi')) (1)
#
# 하고/Verb
#   > (('하', 'Verb'), ('고', 'Eomi')) (64137)
#   > (('직하', 'Verb'), ('고', 'Eomi')) (1)
#   > (('당하', 'Verb'), ('고', 'Eomi')) (1)
#
# 할/Verb
#   > (('하', 'Verb'), ('ᆯ', 'Eomi')) (59709)
#   > (('하', 'Verb'), ('ㄹ', 'Eomi')) (3186)
#   > (('하', 'Verb'), ('ᆫ', 'Eomi')) (6)
#   > (('하', 'Verb'), ('ᆯ', 'Josa')) (3)
#   > (('하', 'Verb'), ('아도', 'Eomi')) (1)
#
# 와/Josa
#   > (('와', 'Josa'),) (60734)
#   > (('과', 'Josa'),) (1)
#
# 있다/Verb
#   > (('있', 'Verb'), ('다', 'Eomi')) (58104)
#
# 있는/Verb
#   > (('있', 'Verb'), ('는', 'Eomi')) (55464)
#   > (('있', 'Verb'), ('는', 'Noun')) (1)
#
# 한/Verb
#   > (('하', 'Verb'), ('ᆫ', 'Eomi')) (50312)
#   > (('하', 'Verb'), ('ㄴ', 'Eomi')) (1504)
#   > (('당하', 'Verb'), ('ᆫ', 'Eomi')) (5)
#   > (('하', 'Verb'), ('ᆫ', 'Josa')) (3)
#   > (('한', 'Verb'), ('ㄴ', 'Eomi')) (2)
#   > (('히', 'Verb'), ('ㄴ', 'Eomi')) (1)
#   > (('하', 'Verb'), ('ᆫ다는', 'Eomi')) (1)
#   > (('위하', 'Verb'), ('ᆫ', 'Eomi')) (1)
#
# 했다/Verb
#   > (('하', 'Verb'), ('았다', 'Eomi')) (47601)
#   > (('하', 'Verb'), ('ㅕㅆ다', 'Eomi')) (168)
#
# 한다/Verb
#   > (('하', 'Verb'), ('ᆫ다', 'Eomi')) (40124)
#   > (('하', 'Verb'), ('ㄴ다', 'Eomi')) (306)
#   > (('하', 'Verb'), ('다', 'Eomi')) (1)
#
# 에는/Josa
#   > (('에는', 'Josa'),) (33243)
#   > (('엔', 'Josa'),) (36)
#   > (('에', 'Josa'),) (3)
#   > (('이에는', 'Josa'),) (1)
#   > (('에서에는', 'Josa'),) (1)
#   > (('에서는', 'Josa'),) (1)
#   > (('에이는', 'Josa'),) (1)
#
# 해/Verb
#   > (('하', 'Verb'), ('아', 'Eomi')) (27370)
#   > (('하', 'Verb'), ('ㅕ', 'Eomi')) (4960)
#   > (('하', 'Verb'),) (1)
#   > (('위하', 'Verb'), ('아', 'Eomi')) (1)
#   > (('당하', 'Verb'), ('아', 'Eomi')) (1)
#   > (('보', 'Verb'), ('ㅏ', 'Eomi')) (1)
#
# 된/Verb
#   > (('되', 'Verb'), ('ᆫ', 'Eomi')) (29943)
#   > (('되', 'Verb'), ('ㄴ', 'Eomi')) (841)
#   > (('되', 'Verb'), ('ᆫ', 'Josa')) (3)
#
# 에게/Josa
#   > (('에게', 'Josa'),) (28208)
#
# 하게/Adjective
#   > (('하', 'Adjective'), ('게', 'Eomi')) (22951)
#   > (('하이', 'Adjective'), ('게', 'Eomi')) (1)
#
# 같은/Adjective
#   > (('같', 'Adjective'), ('은', 'Eomi')) (22877)
#   > (('같', 'Adjective'), ('은', 'Josa')) (6)
#   > (('똑같', 'Adjective'), ('은', 'Eomi')) (1)
#
# 이었다/Adjective
#   > (('이', 'Adjective'), ('었다', 'Eomi')) (22528)
#   > (('이', 'Adjective'), ('었', 'Verb'), ('다', 'Eomi')) (1)
#
# 이나/Josa
#   > (('이나', 'Josa'),) (21786)
#   > (('이나아', 'Josa'),) (8)
#   > (('나', 'Josa'),) (4)
#   > (('에서이나', 'Josa'),) (2)
#   > (('이니', 'Josa'),) (1)
#   > (('이', 'Josa'),) (1)
#
# 까지/Josa
#   > (('까지', 'Josa'),) (21285)
#   > (('에까지', 'Josa'),) (3)
#
# 있었다/Verb
#   > (('있', 'Verb'), ('었다', 'Eomi')) (21008)
#
# 만/Josa
#   > (('만', 'Josa'),) (20947)
#   > (('에만', 'Josa'),) (6)
#
# 대한/Verb
#   > (('대하', 'Verb'), ('ᆫ', 'Eomi')) (19920)
#   > (('대하', 'Verb'), ('ㄴ', 'Eomi')) (586)
#   > (('대하', 'Verb'), ('ㅕㄴ', 'Eomi')) (1)
#
# 처럼/Josa
#   > (('처럼', 'Josa'),) (18547)
#
# 되는/Verb
#   > (('되', 'Verb'), ('는', 'Eomi')) (18527)
#   > (('되', 'Verb'), ('는', 'Josa')) (1)
#
# 하여/Verb
#   > (('하', 'Verb'), ('아', 'Eomi')) (17474)
#   > (('하', 'Verb'), ('여', 'Eomi')) (54)
#   > (('하', 'Verb'), ('어', 'Eomi')) (4)
#   > (('하', 'Verb'), ('ㅕ', 'Eomi')) (3)
#   > (('하', 'Verb'), ('고', 'Eomi')) (1)
#
# 된다/Verb
#   > (('되', 'Verb'), ('ᆫ다', 'Eomi')) (16705)
#   > (('되', 'Verb'), ('ㄴ다', 'Eomi')) (308)
#   > (('되', 'Verb'), ('다', 'Eomi')) (1)
#
# 하지/Verb
#   > (('하', 'Verb'), ('지', 'Eomi')) (16818)
#   > (('당하', 'Verb'), ('지', 'Eomi')) (1)
#
# 나/Josa
#   > (('나', 'Josa'),) (16397)
#   > (('이나', 'Josa'),) (85)
#   > (('을하나', 'Josa'),) (1)
#
# 없는/Adjective
#   > (('없', 'Adjective'), ('는', 'Eomi')) (15697)
#
# 될/Verb
#   > (('되', 'Verb'), ('ᆯ', 'Eomi')) (14406)
#   > (('되', 'Verb'), ('ㄹ', 'Eomi')) (914)
#
# 되어/Verb
#   > (('되', 'Verb'), ('어', 'Eomi')) (15266)
#   > (('되', 'Verb'), ('ㅓ', 'Eomi')) (1)
#
# 에서는/Josa
#   > (('에서는', 'Josa'),) (14882)
#   > (('에서', 'Josa'),) (7)
#   > (('에선', 'Josa'),) (4)
#
# 부터/Josa
#   > (('부터', 'Josa'),) (12783)
#   > (('으로부터', 'Josa'),) (1)
#   > (('부터부터', 'Josa'),) (1)
#
# 아니라/Verb
#   > (('아니', 'Verb'), ('라', 'Eomi')) (12722)
#
# 에도/Josa
#   > (('에도', 'Josa'),) (12309)
#   > (('에', 'Josa'),) (1)
#   > (('이에도', 'Josa'),) (1)
#   > (('에서에도', 'Josa'),) (1)
#
# 되고/Verb
#   > (('되', 'Verb'), ('고', 'Eomi')) (12287)
#
# 해서/Verb
#   > (('하', 'Verb'), ('아서', 'Eomi')) (9880)
#   > (('하', 'Verb'), ('ㅕ서', 'Eomi')) (1893)
#   > (('하', 'Verb'), ('아하아서', 'Eomi')) (1)
#
# 해야/Verb
#   > (('하', 'Verb'), ('아야', 'Eomi')) (10647)
#   > (('하', 'Verb'), ('ㅕ야', 'Eomi')) (1076)
#   > (('하', 'Verb'), ('아야하', 'Eomi')) (1)
#
# 하면/Verb
#   > (('하', 'Verb'), ('면', 'Eomi')) (11683)
#
# 없다/Adjective
#   > (('없', 'Adjective'), ('다', 'Eomi')) (11176)
#
# 보다/Josa
#   > (('보다', 'Josa'),) (10964)
#   > (('에서보다', 'Josa'),) (1)
#
# 이라고/Adjective
#   > (('이', 'Adjective'), ('라고', 'Eomi')) (10779)
#   > (('이', 'Adjective'), ('고', 'Eomi')) (25)
#   > (('이', 'Adjective'), ('라고', 'Josa')) (2)
#
# 위해/Verb
#   > (('위하', 'Verb'), ('아', 'Eomi')) (10664)
#   > (('위하', 'Verb'), ('ㅕ', 'Eomi')) (42)
#
# 되었다/Verb
#   > (('되', 'Verb'), ('었다', 'Eomi')) (10289)
#
# 이라는/Adjective
#   > (('이', 'Adjective'), ('라는', 'Eomi')) (10255)
#   > (('이', 'Adjective'), ('는', 'Eomi')) (5)
#   > (('이', 'Adjective'),) (2)
#   > (('(이)', 'Adjective'), ('라는', 'Eomi')) (2)
#   > (('이', 'Adjective'), ('라는라는', 'Eomi')) (1)
#
# 하였다/Verb
#   > (('하', 'Verb'), ('았다', 'Eomi')) (10238)
#   > (('하', 'Verb'), ('었다', 'Eomi')) (7)
#   > (('하', 'Verb'), ('였다', 'Eomi')) (4)
#   > (('하', 'Verb'), ('았다79', 'Eomi')) (1)
#
#  의/Josa
#   > (('의', 'Josa'),) (9833)
#   > (('에서의', 'Josa'),) (1)
#
# 야/Adjective
#   > (('이', 'Adjective'), ('야', 'Eomi')) (5453)
#   > (('(이)', 'Adjective'), ('야', 'Eomi')) (4070)
#   > (('이', 'Adjective'), ('아', 'Eomi')) (21)
#   > (('ㅣ', 'Adjective'), ('야', 'Eomi')) (6)
#   > (('이', 'Adjective'), ('ㅑ', 'Eomi')) (3)
#   > (('이', 'Adjective'), ('야', 'Josa')) (1)
#   > (('(이)', 'Adjective'), ('야', 'Exclamation')) (1)
#
# 있을/Verb
#   > (('있', 'Verb'), ('을', 'Eomi')) (9520)
#   > (('만하', 'Verb'), ('ㄴ', 'Eomi')) (1)
#   > (('있', 'Verb'), ('을걸', 'Eomi')) (1)
#
# 하다/Adjective
#   > (('하', 'Adjective'), ('다', 'Eomi')) (9470)
#
# 따라/Verb
#   > (('따르', 'Verb'), ('아', 'Eomi')) (9337)
#   > (('따르', 'Verb'), ('ㅏ', 'Eomi')) (118)
#   > (('따', 'Verb'), ('라', 'Eomi')) (2)
#   > (('따르', 'Verb'), ('어', 'Eomi')) (1)
#   > (('따', 'Verb'), ('아', 'Eomi')) (1)
#   > (('따르', 'Verb'), ('라', 'Eomi')) (1)
#
# 이고/Adjective
#   > (('이', 'Adjective'), ('고', 'Eomi')) (9357)
#   > (('이', 'Adjective'), ('라고', 'Eomi')) (20)
#   > (('이', 'Adjective'), ('구', 'Eomi')) (1)
#
# 많은/Adjective
#   > (('많', 'Adjective'), ('은', 'Eomi')) (9282)
#
# 큰/Adjective
#   > (('크', 'Adjective'), ('ᆫ', 'Eomi')) (8840)
#   > (('크', 'Adjective'), ('ㄴ', 'Eomi')) (304)
#
# 였다/Adjective
#   > (('이', 'Adjective'), ('었다', 'Eomi')) (9015)
#   > (('이', 'Adjective'), ('ㅓㅆ다', 'Eomi')) (29)
#
# 다/Adjective
#   > (('이', 'Adjective'), ('다', 'Eomi')) (8665)
#   > (('(이)', 'Adjective'), ('다', 'Eomi')) (343)
#   > (('없', 'Adjective'), ('다', 'Eomi')) (2)
#   > (('이', 'Adjective'), ('ㅓㅆ다', 'Eomi')) (1)
#   > (('이', 'Adjective'),) (1)
#
# 입니다/Adjective
#   > (('이', 'Adjective'), ('ᄇ니다', 'Eomi')) (7939)
#   > (('이', 'Adjective'), ('ㅂ니다', 'Eomi')) (777)
#   > (('(이)', 'Adjective'), ('ㅂ니다', 'Eomi')) (2)
#
# 하고/Adjective
#   > (('하', 'Adjective'), ('고', 'Eomi')) (8561)
#
# 않고/Verb
#   > (('않', 'Verb'), ('고', 'Eomi')) (8501)
#
#  을/Josa
#   > (('을', 'Josa'),) (8362)
#   > (('에서을', 'Josa'),) (1)
#
# 하게/Verb
#   > (('하', 'Verb'), ('게', 'Eomi')) (8244)
#   > (('고', 'Verb'), ('ᆫ하게', 'Eomi')) (1)
#
# 하며/Verb
#   > (('하', 'Verb'), ('며', 'Eomi')) (8114)
#   > (('하', 'Verb'), ('며', 'Josa')) (1)
#
# 서/Josa
#   > (('서', 'Josa'),) (7953)
#   > (('에서', 'Josa'),) (114)
#   > (('으로서', 'Josa'),) (2)
#
# 하면서/Verb
#   > (('하', 'Verb'), ('면서', 'Eomi')) (7763)
#   > (('당하', 'Verb'), ('면서', 'Eomi')) (1)
#
# 없었다/Adjective
#   > (('없', 'Adjective'), ('었다', 'Eomi')) (7720)
#
# 어떻게/Adjective
#   > (('어떻', 'Adjective'), ('게', 'Eomi')) (7720)
#
# 않았다/Verb
#   > (('않', 'Verb'), ('았다', 'Eomi')) (7674)
#
# 이렇게/Adjective
#   > (('이렇', 'Adjective'), ('게', 'Eomi')) (7436)
#
# 있다는/Verb
#   > (('있', 'Verb'), ('다는', 'Eomi')) (7262)
#
# 볼/Verb
#   > (('보', 'Verb'), ('ᆯ', 'Eomi')) (6643)
#   > (('보', 'Verb'), ('ㄹ', 'Eomi')) (611)
#
# 위한/Verb
#   > (('위하', 'Verb'), ('ᆫ', 'Eomi')) (7079)
#   > (('위하', 'Verb'), ('ㄴ', 'Eomi')) (156)
#
# 그렇게/Adjective
#   > (('그렇', 'Adjective'), ('게', 'Eomi')) (7150)
#
# 보면/Verb
#   > (('보', 'Verb'), ('면', 'Eomi')) (7118)
#
# 라는/Adjective
#   > (('이', 'Adjective'), ('라는', 'Eomi')) (6460)
#   > (('(이)', 'Adjective'), ('라는', 'Eomi')) (628)
#   > (('이', 'Adjective'), ('아라는', 'Eomi')) (1)
#
# 라고/Adjective
#   > (('이', 'Adjective'), ('라고', 'Eomi')) (6079)
#   > (('(이)', 'Adjective'), ('라고', 'Eomi')) (979)
#   > (('이', 'Adjective'), ('ᆯ라고', 'Eomi')) (4)
#   > (('이', 'Adjective'), ('라고', 'Josa')) (1)
#   > (('(이)', 'Adjective'), ('라', 'Eomi')) (1)
#   > (('(이)', 'Adjective'), ('라고', 'Josa')) (1)
#
#  를/Josa
#   > (('를', 'Josa'),) (6990)
#   > (('을', 'Josa'),) (2)
#
# 있고/Verb
#   > (('있', 'Verb'), ('고', 'Eomi')) (6927)
#
# 가지고/Verb
#   > (('가지', 'Verb'), ('고', 'Eomi')) (6816)
#
# 한다는/Verb
#   > (('하', 'Verb'), ('ᆫ다는', 'Eomi')) (6568)
#   > (('하', 'Verb'), ('ㄴ다는', 'Eomi')) (185)
#
# 이며/Adjective
#   > (('이', 'Adjective'), ('며', 'Eomi')) (6682)
#
# 인가/Adjective
#   > (('이', 'Adjective'), ('ᆫ가', 'Eomi')) (6145)
#   > (('이', 'Adjective'), ('ㄴ가', 'Eomi')) (530)
#   > (('(이)', 'Adjective'), ('ㄴ가', 'Eomi')) (2)
#   > (('이', 'Adjective'),) (1)
#
# 통해/Verb
#   > (('통하', 'Verb'), ('아', 'Eomi')) (6471)
#   > (('통하', 'Verb'), ('ㅕ', 'Eomi')) (55)
#
# 에서도/Josa
#   > (('에서도', 'Josa'),) (6480)
#   > (('에서', 'Josa'),) (2)
#
# 새로운/Adjective
#   > (('새롭', 'Adjective'), ('ᆫ', 'Eomi')) (6325)
#   > (('새롭', 'Adjective'), ('은', 'Eomi')) (133)
